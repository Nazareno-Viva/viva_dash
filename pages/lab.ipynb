# %%
import streamlit as st
import pandas as pd
import plotly.express as px
from datetime import datetime
import locale
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# locale.setlocale(locale.LC_TIME, 'pt_BR.UTF-8')

# %%
df = pd.read_csv(os.environ["NDS"])

# %%
_colunas = ['Idade', 
            'Estado Civil',
            'Qual a sua decisão hoje?',
            'Data da decisão', 
            'A decisão ocorreu em qual culto?',
            'Você é batizado nas águas em alguma igreja Evangélica?',
            'Como chegou à VIVA?']


_coluna_rename = {'Qual a sua decisão hoje?':'Decisão',
                  'Data da decisão':'Data',
                  'A decisão ocorreu em qual culto?':'Período do culto',
                  'Você é batizado nas águas em alguma igreja Evangélica?':'Batizado',
                  'Como chegou à VIVA?':'Forma de convite'}

_idade_ordem = {'30 - 40 anos':5, 
                '> 40 anos':6,  
                '18 - 24 anos':3,
                '11 - 14 anos':1,
                '15 - 17 anos':2, 
                '25 - 29 anos':4}
meses = {
    1: "Janeiro",
    2: "Fevereiro",
    3: "Março",
    4: "Abril",
    5: "Maio",
    6: "Junho",
    7: "Julho",
    8: "Agosto",
    9: "Setembro",
    10: "Outubro",
    11: "Novembro",
    12: "Dezembro"
}

# %%
df = df[_colunas].copy()
df.rename(columns=_coluna_rename, inplace = True)
df['Data'] = pd.to_datetime(df['Data'])
df['Mês-Numério'] = df['Data'].dt.month
df['Mês'] = df['Mês-Numério'].map(meses)
df['Ano'] = df['Data'].dt.year.astype(str)
df['Mês - Ano'] = df['Mês'] + '-' + df['Ano']
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.sort_values(by=['Data'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df['Mês'].unique()
# Out:
# array(['Junho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro',
#        'Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio'], dtype=object)

# %%
df.sort_values(by=['Mês-Numério'], inplace=True)

# %%
df.tail()
# Out:
#            Idade    Estado Civil        Decisão       Data Período do culto  \
# 22     > 40 anos      Casado (a)      Conversão 2024-11-03    Pequeno Grupo
# 23  30 - 40 anos  Divorciado (a)  Reconciliação 2024-11-03      Domingo 10h
# 24  30 - 40 anos      Casado (a)  Reconciliação 2024-11-17      Domingo 10h
# 25     > 40 anos      Casado (a)      Conversão 2024-12-15      Domingo 19h
# 26  30 - 40 anos      Casado (a)      Conversão 2024-12-15      Domingo 19h
#
#    Batizado              Forma de convite  Mês-Numério       Mês   Ano  \
# 22      Não              Convite de amigo           11  Novembro  2024
# 23      Sim              Convite de amigo           11  Novembro  2024
# 24      Sim             Convicção pessoal           11  Novembro  2024
# 25      Não  Convite de alguém da família           12  Dezembro  2024
# 26      Sim  Convite de alguém da família           12  Dezembro  2024
#
#         Mês - Ano
# 22  Novembro-2024
# 23  Novembro-2024
# 24  Novembro-2024
# 25  Dezembro-2024
# 26  Dezembro-2024

# %%
# fig = px.pie(df, 
#              names='Mês',
#              color_discrete_sequence=px.colors.qualitative.G10)

# fig.update_layout(template='plotly_dark',
#                   title='Mês',
#                   title_x=0.5)
# fig.update_traces(textposition='outside')  # Coloca o texto acima das barras

# fig.show()

# %%
did = df.groupby(['Idade', 'Decisão']).size().reset_index(name='N')
did['Idade ordenada'] = did['Idade'].map(_idade_ordem)

# %%
# fig = px.bar(did, 
#              x='Idade', 
#              y='N', 
#              color='Decisão', 
#              barmode='group', 
#              text='N',
#              color_discrete_sequence=px.colors.qualitative.G10)

# fig.update_layout(template='plotly_dark',
#                   yaxis_title='Quantidade de Decisões',
#                   title='Decisões por Faixa Etária',
#                   title_x=0.5)
# fig.update_traces(textposition='outside') 

# fig.show()

# %%
dib = df.groupby(['Idade', 'Batizado']).size().reset_index(name='N')
dib['Idade ordenada'] = dib['Idade'].map(_idade_ordem)

# %%
# fig = px.bar(dib, 
#              x='Idade', 
#              y='N', 
#              color='Batizado', 
#              barmode='group', 
#              text='N',
#              color_discrete_sequence=px.colors.qualitative.G10)

# fig.update_layout(template='plotly_dark',
#                   yaxis_title='Quantidade de Batizado e Não Batizados',
#                   title='Batizados por Faixa Etária',
#                   title_x=0.5)
# fig.update_traces(textposition='outside')  # Coloca o texto acima das barras

# fig.show()

# %%
# fig = px.pie(df, 
#              names='Estado Civil',
#              color_discrete_sequence=px.colors.qualitative.G10)

# fig.update_layout(template='plotly_dark',
#                   title='Estado Civil',
#                   title_x=0.5)
# fig.update_traces(textposition='outside')  # Coloca o texto acima das barras

# fig.show()

# %%
# fig = px.pie(df, 
#              names='Forma de convite',
#              color_discrete_sequence=px.colors.qualitative.G10)

# fig.update_layout(template='plotly_dark',
#                   title='Forma de convite',
#                   title_x=0.5)
# fig.update_traces(textposition='outside')  # Coloca o texto acima das barras

# fig.show()

# %%
dip = df.groupby(['Idade', 'Período do culto']).size().reset_index(name='N')
dip['Idade ordenada'] = dip['Idade'].map(_idade_ordem)

# %%
# fig = px.bar(dip, 
#              x='Idade', 
#              y='N', 
#              color='Período do culto', 
#              barmode='group', 
#              text='N',
#              color_discrete_sequence=px.colors.qualitative.G10)

# fig.update_layout(template='plotly_dark',
#                   yaxis_title='Quantidade de Batizado e Não Batizados',
#                   title='Local da Decisão por Faixa Etária',
#                   title_x=0.5)
# fig.update_traces(textposition='outside')  # Coloca o texto acima das barras

# fig.show()
